# %%
import pandas as pd
from sklearn import datasets
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
import mlflow
from mlflow.models import infer_signature

# %%
# set the tracking uri
mlflow.set_tracking_uri(uri = "http://127.0.0.1:5000")

# %%
## load the datast
X,y = datasets.load_iris(return_X_y=True)

#Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.20)

# Define the model hyperparameter
params = {"penalty": "l2", "solver": "lbfgs", "max_iter" : 1000, "multi_class": "auto", "random_state": 8888}

# train the model
lr=LogisticRegression(**params)
lr.fit(X_train,y_train)
# Out:
# c:\Users\shipr\AI_ML_Practice\MLOps\venv\lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# LogisticRegression(max_iter=1000, multi_class='auto', random_state=8888)

# %%
## Prediction on the test set

y_pred= lr.predict(X_test)
y_pred
# Out:
# array([2, 2, 1, 0, 0, 2, 0, 0, 0, 0, 0, 2, 1, 0, 2, 0, 2, 2, 2, 1, 2, 1,
#        0, 1, 1, 1, 0, 1, 2, 2])

# %%
accuracy = accuracy_score(y_test,y_pred)
print(accuracy)
# Out:
# 0.9333333333333333

# %%
## MLflow Tracking

# create a new MLFlow experiment
mlflow.set_experiment("MLFlow quickstart")

with mlflow.start_run():
    # log hyperparameters
    mlflow.log_params(params)

    ## log the accuracy metrics
    mlflow.log_metric("accuracy", accuracy)

    # set a tag for experiment so that we can use to remind ourselves what this run was for
    mlflow.set_tag("Training Info", "Basic LR model for Iris Data")

    #Infer the model signature
    signature = infer_signature(X_train, lr.predict(X_train))

    ## log the model
    model_info=mlflow.sklearn.log_model(
        sk_model=lr,
        artifact_path="iris_model",
        signature= signature,
        input_example=X_train,
        registered_model_name="tracking-quickstart",
    )
# Out:
# 2024/11/25 17:55:45 INFO mlflow.tracking.fluent: Experiment with name 'MLFlow quickstart' does not exist. Creating a new experiment.
# Successfully registered model 'tracking-quickstart'.
# 2024/11/25 17:55:57 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: tracking-quickstart, version 1
# 🏃 View run gaudy-fish-400 at: http://127.0.0.1:5000/#/experiments/842748552404069022/runs/87f3ace7b7d443c28638d9125d592c1a
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/842748552404069022
# Created version '1' of model 'tracking-quickstart'.

# %% [markdown]
# ## Inferencing and Validating Model

# %%
from mlflow.models import validate_serving_input

#model_uri = 'runs:/87f3ace7b7d443c28638d9125d592c1a/iris_model'
model_uri = model_info.model_uri

# The model is logged with an input example. MLflow converts
# it into the serving payload format for the deployed model endpoint,
# and saves it to 'serving_input_payload.json'
serving_payload = """{
  "inputs": [
    [
      5.8,
      2.7,
      3.9,
      1.2
    ],
    [
      4.5,
      2.3,
      1.3,
      0.3
    ],
    [
      6.6,
      3.0,
      4.4,
      1.4
    ],
    [
      6.3,
      3.3,
      6.0,
      2.5
    ],
    [
      7.4,
      2.8,
      6.1,
      1.9
    ],
    [
      6.1,
      2.8,
      4.0,
      1.3
    ],
    [
      5.0,
      3.5,
      1.6,
      0.6
    ],
    [
      6.0,
      2.2,
      4.0,
      1.0
    ],
    [
      6.7,
      3.1,
      5.6,
      2.4
    ],
    [
      5.0,
      3.6,
      1.4,
      0.2
    ],
    [
      6.9,
      3.1,
      5.4,
      2.1
    ],
    [
      5.8,
      2.7,
      5.1,
      1.9
    ],
    [
      6.8,
      3.2,
      5.9,
      2.3
    ],
    [
      4.8,
      3.0,
      1.4,
      0.1
    ],
    [
      6.7,
      3.3,
      5.7,
      2.1
    ],
    [
      6.4,
      2.9,
      4.3,
      1.3
    ],
    [
    ],
    [
      5.1,
      3.5,
      1.4,
      0.3
    ],
    [
      6.1,
      3.0,
      4.9,
      1.8
    ],
    [
      6.7,
      3.3,
      5.7,
      2.5
    ],
    [
      7.1,
      3.0,
      5.9,
      2.1
    ],
    [
      4.6,
      3.4,
      1.4,
      0.3
    ],
    [
      6.2,
      3.4,
      5.4,
      2.3
    ],
    [
      5.5,
      4.2,
      1.4,
      0.2
    ],
    [
      6.2,
      2.9,
      4.3,
      1.3
    ],
    [
      6.5,
      3.0,
      5.8,
      2.2
    ],
    [
      4.9,
      3.1,
      1.5,
      0.2
    ],
    [
      4.8,
      3.4,
      1.6,
      0.2
    ],
    [
      5.6,
      2.5,
      3.9,
      1.1
    ],
    [
      6.4,
      2.7,
      5.3,
      1.9
    ],
    [
      5.1,
      3.8,
      1.6,
      0.2
    ],
    [
      6.2,
      2.2,
      4.5,
      1.5
    ],
    [
      4.9,
      2.5,
      4.5,
      1.7
    ],
    [
      4.9,
      2.4,
      3.3,
      1.0
    ],
    [
      5.5,
      2.3,
      4.0,
      1.3
    ],
    [
      6.8,
      3.0,
      5.5,
      2.1
    ],
    [
      4.4,
      3.2,
      1.3,
      0.2
    ],
    [
      4.8,
      3.4,
      1.9,
      0.2
    ],
    [
      7.2,
      3.2,
      6.0,
      1.8
    ],
    [
      5.7,
      2.8,
      4.5,
      1.3
    ],
    [
      5.8,
      2.7,
      4.1,
      1.0
    ],
    [
      4.6,
      3.6,
      1.0,
      0.2
    ],
    [
      5.7,
      3.8,
      1.7,
      0.3
    ],
    [
      6.0,
      2.9,
      4.5,
      1.5
    ],
    [
      6.4,
      3.2,
      4.5,
      1.5
    ],
    [
      5.7,
      2.5,
      5.0,
      2.0
    ],
    [
      6.1,
      3.0,
      4.6,
      1.4
    ],
    [
      6.3,
      2.9,
      5.6,
      1.8
    ],
    [
      4.3,
      3.0,
      1.1,
      0.1
    ],
    [
      6.3,
      2.8,
      5.1,
      1.5
    ],
    [
      5.6,
      2.8,
      4.9,
      2.0
    ],
    [
      5.5,
      2.4,
      3.7,
      1.0
    ]
  ]
}"""

# Validate the serving payload works on the model
validate_serving_input(model_uri, serving_payload)
# Out:
# array([1, 0, 1, 2, 2, 1, 0, 1, 2, 0, 2, 2, 2, 0, 2, 1, 0, 1, 0, 1, 1, 0,
#        1, 0, 2, 0, 1, 0, 0, 1, 1, 0, 0, 2, 1, 1, 0, 0, 0, 1, 2, 2, 1, 1,
#        2, 0, 2, 2, 0, 2, 2, 1, 2, 0, 0, 0, 0, 2, 2, 2, 2, 0, 1, 2, 1, 0,
#        2, 2, 2, 1, 1, 0, 0, 0, 1, 1, 1, 2, 2, 1, 2, 2, 1, 1, 0, 0, 2, 2,
#        2, 0, 2, 0, 1, 2, 0, 0, 1, 2, 0, 1, 2, 1, 1, 2, 0, 0, 2, 1, 1, 0,
#        0, 1, 1, 2, 1, 2, 0, 2, 2, 1])

# %% [markdown]
# ## Load the model back for prediction as a generic python function model

# %%
loaded_model = mlflow.pyfunc.load_model(model_info.model_uri)
predictions=loaded_model.predict(X_test)

iris_features_name=datasets.load_iris().feature_names

result = pd.DataFrame(X_test, columns=iris_features_name)
result["actual_class"]=y_test
result["predicted_class"] = y_pred

result[:5]
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.8               2.8                5.1               2.4
# 1                6.4               3.2                5.3               2.3
# 2                5.6               3.0                4.1               1.3
# 3                5.0               3.5                1.3               0.3
# 4                4.9               3.0                1.4               0.2
#
#    actual_class  predicted_class
# 0             2                2
# 1             2                2
# 2             1                1
# 3             0                0
# 4             0                0

# %% [markdown]
# ## Model Registery
#
# ### The MLflow Model Registry component is a centralized model store, set of API's an UI, to collaborately manage the full lifecycle of MLflow modl. It provides model lineage ( which MLflow experiment and run produce the model), model versioning, model aliasing,model tagging, and annotations
